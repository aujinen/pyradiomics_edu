# %% [markdown]
# ## sample for check radiomics_2d
# by H.Nishiyama
# 2026-06-25 12:28:09

# %%
import os
import SimpleITK as sitk
import six
from radiomics import featureextractor, getTestCase

# %%
dataDir = './'

imageName = os.path.join(dataDir, 'forRadiomicsTest.nrrd')
maskName = os.path.join(dataDir, 'Segmentation.seg.nrrd')

# %%
params = os.path.join(dataDir, '2D_sample.yaml')

# %%
extractor = featureextractor.RadiomicsFeatureExtractor(params)

# %%
results = extractor.execute(imageName, maskName)

# %%
for key, val in six.iteritems(results):
    print("\t%s: %s" % (key, val))
# Out:
# 	diagnostics_Versions_PyRadiomics: 0.1.dev1340+g15a938dad.d20260625
# 	diagnostics_Versions_Numpy: 2.5.0
# 	diagnostics_Versions_SimpleITK: 2.5.5
# 	diagnostics_Versions_PyWavelet: 1.8.0
# 	diagnostics_Versions_Python: 3.13.0
# 	diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': True, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 1}
# 	diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# 	diagnostics_Image-original_Hash: d3109711f03bad3ee674d20eadf752f499f3dee4
# 	diagnostics_Image-original_Dimensionality: 3D
# 	diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Image-original_Size: (8, 8, 1)
# 	diagnostics_Image-original_Mean: 1.953125
# 	diagnostics_Image-original_Minimum: 1.0
# 	diagnostics_Image-original_Maximum: 4.0
# 	diagnostics_Mask-original_Hash: fa1dd549a81e76ed8f8a7eb2c2097b589449d671
# 	diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Mask-original_Size: (8, 8, 1)
# 	diagnostics_Mask-original_BoundingBox: (0, 0, 0, 8, 8, 1)
# 	diagnostics_Mask-original_VoxelNum: 64
# 	diagnostics_Mask-original_VolumeNum: 1
# 	diagnostics_Mask-original_CenterOfMassIndex: (np.float64(3.5), np.float64(3.5), np.float64(0.0))
# 	diagnostics_Mask-original_CenterOfMass: (3.5, 3.5, 0.0)
# 	original_shape2D_Elongation: (1+0j)
# 	original_shape2D_MajorAxisLength: (9.16515138991168+0j)
# 	original_shape2D_MaximumDiameter: 10.63014581273465
# 	original_shape2D_MeshSurface: 63.5
# 	original_shape2D_MinorAxisLength: (9.16515138991168+0j)
# 	original_shape2D_Perimeter: 30.828427124746188
# 	original_shape2D_PerimeterSurfaceRatio: 0.48548704133458565
# 	original_shape2D_PixelSurface: 64.0
# 	original_shape2D_Sphericity: 0.9163057823606817
# 	original_firstorder_10Percentile: 1.0
# 	original_firstorder_90Percentile: 3.700000000000003
# 	original_firstorder_Energy: 305.0
# 	original_firstorder_Entropy: 1.784578293498763
# 	original_firstorder_InterquartileRange: 1.0
# 	original_firstorder_Kurtosis: 2.645726376431388
# 	original_firstorder_Maximum: 4.0
# 	original_firstorder_MeanAbsoluteDeviation: 0.74462890625
# 	original_firstorder_Mean: 1.953125
# 	original_firstorder_Median: 2.0
# 	original_firstorder_Minimum: 1.0
# 	original_firstorder_Range: 3.0
# 	original_firstorder_RobustMeanAbsoluteDeviation: 0.6155740227762388
# 	original_firstorder_RootMeanSquared: 2.1830311495716224
# 	original_firstorder_Skewness: 0.8014671399633715
# 	original_firstorder_TotalEnergy: 305.0
# 	original_firstorder_Uniformity: 0.32080078125
# 	original_firstorder_Variance: 0.9509277343749999
# 	original_glcm_Autocorrelation: 4.115433673469388
# 	original_glcm_JointAverage: 2.0181760204081636
# 	original_glcm_ClusterProminence: 12.559747185476569
# 	original_glcm_ClusterShade: 1.9902340678761605
# 	original_glcm_ClusterTendency: 2.0091351910662225
# 	original_glcm_Contrast: 1.8437499999999998
# 	original_glcm_Correlation: 0.04252529440862567
# 	original_glcm_DifferenceAverage: 1.0338010204081631
# 	original_glcm_DifferenceEntropy: 1.7443228620515558
# 	original_glcm_DifferenceVariance: 0.7583998203873386
# 	original_glcm_JointEnergy: 0.10470409464806331
# 	original_glcm_JointEntropy: 3.536126084150986
# 	original_glcm_Imc1: -0.04887176163476051
# 	original_glcm_Imc2: 0.3965799668439691
# 	original_glcm_Idm: 0.564094387755102
# 	original_glcm_Idmn: 0.9098079231692677
# 	original_glcm_Id: 0.6024659863945577
# 	original_glcm_Idn: 0.8184523809523809
# 	original_glcm_InverseVariance: 0.47266510770975056
# 	original_glcm_MaximumProbability: 0.18112244897959182
# 	original_glcm_SumEntropy: 2.4018021625921318
# 	original_glcm_SumSquares: 0.9632212977665556
# 	original_glrlm_GrayLevelNonUniformity: 14.481798941798942
# 	original_glrlm_GrayLevelNonUniformityNormalized: 0.3029449287533944
# 	original_glrlm_GrayLevelVariance: 1.0344328014333306
# 	original_glrlm_HighGrayLevelRunEmphasis: 5.062089947089947
# 	original_glrlm_LongRunEmphasis: 2.2864550264550267
# 	original_glrlm_LongRunHighGrayLevelEmphasis: 9.996957671957674
# 	original_glrlm_LongRunLowGrayLevelEmphasis: 1.1839460243974134
# 	original_glrlm_LowGrayLevelRunEmphasis: 0.5002109053497943
# 	original_glrlm_RunEntropy: 2.750381735940963
# 	original_glrlm_RunLengthNonUniformity: 29.372116402116404
# 	original_glrlm_RunLengthNonUniformityNormalized: 0.604869359760365
# 	original_glrlm_RunPercentage: 0.74609375
# 	original_glrlm_RunVariance: 0.4395111671005851
# 	original_glrlm_ShortRunEmphasis: 0.7966852219282775
# 	original_glrlm_ShortRunHighGrayLevelEmphasis: 4.244781562316285
# 	original_glrlm_ShortRunLowGrayLevelEmphasis: 0.39775844172545566
# 	original_glszm_GrayLevelNonUniformity: 4.647058823529412
# 	original_glszm_GrayLevelNonUniformityNormalized: 0.27335640138408307
# 	original_glszm_GrayLevelVariance: 1.1833910034602078
# 	original_glszm_HighGrayLevelZoneEmphasis: 7.0
# 	original_glszm_LargeAreaEmphasis: 37.1764705882353
# 	original_glszm_LargeAreaHighGrayLevelEmphasis: 117.70588235294117
# 	original_glszm_LargeAreaLowGrayLevelEmphasis: 21.433415032679736
# 	original_glszm_LowGrayLevelZoneEmphasis: 0.38848039215686275
# 	original_glszm_SizeZoneNonUniformity: 5.0
# 	original_glszm_SizeZoneNonUniformityNormalized: 0.29411764705882354
# 	original_glszm_SmallAreaEmphasis: 0.5163646935850466
# 	original_glszm_SmallAreaHighGrayLevelEmphasis: 4.110929566823846
# 	original_glszm_SmallAreaLowGrayLevelEmphasis: 0.1689245691388179
# 	original_glszm_ZoneEntropy: 3.286895754518758
# 	original_glszm_ZonePercentage: 0.265625
# 	original_glszm_ZoneVariance: 23.003460207612456
# 	original_gldm_DependenceEntropy: 3.522094419775396
# 	original_gldm_DependenceNonUniformity: 15.4375
# 	original_gldm_DependenceNonUniformityNormalized: 0.2412109375
# 	original_gldm_DependenceVariance: 1.3427734375
# 	original_gldm_GrayLevelNonUniformity: 20.53125
# 	original_gldm_GrayLevelVariance: 0.950927734375
# 	original_gldm_HighGrayLevelEmphasis: 4.765625
# 	original_gldm_LargeDependenceEmphasis: 10.53125
# 	original_gldm_LargeDependenceHighGrayLevelEmphasis: 41.265625
# 	original_gldm_LargeDependenceLowGrayLevelEmphasis: 5.295030381944445
# 	original_gldm_LowGrayLevelEmphasis: 0.5050998263888888
# 	original_gldm_SmallDependenceEmphasis: 0.22692274305555554
# 	original_gldm_SmallDependenceHighGrayLevelEmphasis: 1.5104470486111112
# 	original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.0928732940297068
# 	original_ngtdm_Busyness: 6.311277777777778
# 	original_ngtdm_Coarseness: 0.06760384848991664
# 	original_ngtdm_Complexity: 4.959905680814222
# 	original_ngtdm_Contrast: 0.13116529252794054
# 	original_ngtdm_Strength: 0.37759597230962866
