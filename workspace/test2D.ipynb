# %%
import os
import SimpleITK as sitk
import six
from radiomics import featureextractor, getTestCase

# %%
dataDir = './'

imageName = os.path.join(dataDir, 'forRadiomicsTest.nrrd')
maskName = os.path.join(dataDir, 'Segmentation.seg.nrrd')

# %%
params = os.path.join(dataDir, '2D_sample.yaml')

# %%
extractor = featureextractor.RadiomicsFeatureExtractor(params)

# %%
results = extractor.execute(imageName, maskName)

# %%
for key, val in six.iteritems(results):
    print("\t%s: %s" % (key, val))
# Out:
# 	diagnostics_Versions_PyRadiomics: 3.1.1.dev111+g8ed579383.d20260623
# 	diagnostics_Versions_Numpy: 2.4.6
# 	diagnostics_Versions_SimpleITK: 2.5.5
# 	diagnostics_Versions_PyWavelet: 1.8.0
# 	diagnostics_Versions_Python: 3.13.0
# 	diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': True, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 4}
# 	diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# 	diagnostics_Image-original_Hash: d3109711f03bad3ee674d20eadf752f499f3dee4
# 	diagnostics_Image-original_Dimensionality: 3D
# 	diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Image-original_Size: (8, 8, 1)
# 	diagnostics_Image-original_Mean: 1.953125
# 	diagnostics_Image-original_Minimum: 1.0
# 	diagnostics_Image-original_Maximum: 4.0
# 	diagnostics_Mask-original_Hash: fa1dd549a81e76ed8f8a7eb2c2097b589449d671
# 	diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Mask-original_Size: (8, 8, 1)
# 	diagnostics_Mask-original_BoundingBox: (0, 0, 0, 8, 8, 1)
# 	diagnostics_Mask-original_VoxelNum: 64
# 	diagnostics_Mask-original_VolumeNum: 1
# 	diagnostics_Mask-original_CenterOfMassIndex: (np.float64(3.5), np.float64(3.5), np.float64(0.0))
# 	diagnostics_Mask-original_CenterOfMass: (3.5, 3.5, 0.0)
# 	original_shape2D_Elongation: 1.0
# 	original_shape2D_MajorAxisLength: 9.16515138991168
# 	original_shape2D_MaximumDiameter: 10.63014581273465
# 	original_shape2D_MeshSurface: 63.5
# 	original_shape2D_MinorAxisLength: 9.16515138991168
# 	original_shape2D_Perimeter: 30.828427124746188
# 	original_shape2D_PerimeterSurfaceRatio: 0.48548704133458565
# 	original_shape2D_PixelSurface: 64.0
# 	original_shape2D_Sphericity: 0.9163057823606817
# 	original_firstorder_10Percentile: 1.0
# 	original_firstorder_90Percentile: 3.700000000000003
# 	original_firstorder_Energy: 305.0
# 	original_firstorder_Entropy: 0.4980278865344758
# 	original_firstorder_InterquartileRange: 1.0
# 	original_firstorder_Kurtosis: 2.645726376431388
# 	original_firstorder_Maximum: 4.0
# 	original_firstorder_MeanAbsoluteDeviation: 0.74462890625
# 	original_firstorder_Mean: 1.953125
# 	original_firstorder_Median: 2.0
# 	original_firstorder_Minimum: 1.0
# 	original_firstorder_Range: 3.0
# 	original_firstorder_RobustMeanAbsoluteDeviation: 0.6155740227762388
# 	original_firstorder_RootMeanSquared: 2.1830311495716224
# 	original_firstorder_Skewness: 0.8014671399633715
# 	original_firstorder_TotalEnergy: 305.0
# 	original_firstorder_Uniformity: 0.80517578125
# 	original_firstorder_Variance: 0.9509277343749999
# 	original_glcm_Autocorrelation: 1.2627551020408163
# 	original_glcm_JointAverage: 1.1192602040816326
# 	original_glcm_ClusterProminence: 0.29890795127972525
# 	original_glcm_ClusterShade: 0.20514550963034092
# 	original_glcm_ClusterTendency: 0.22989769887546854
# 	original_glcm_Contrast: 0.19005102040816327
# 	original_glcm_Correlation: 0.09444312608764417
# 	original_glcm_DifferenceAverage: 0.19005102040816327
# 	original_glcm_DifferenceEntropy: 0.6996545116042115
# 	original_glcm_DifferenceVariance: 0.15352327155351936
# 	original_glcm_JointEnergy: 0.6365023688046647
# 	original_glcm_JointEntropy: 1.0445266833576219
# 	original_glcm_Imc1: -0.017335852763300366
# 	original_glcm_Imc2: 0.10174505463327421
# 	original_glcm_Idm: 0.9049744897959184
# 	original_glcm_Idmn: 0.9619897959183674
# 	original_glcm_Id: 0.9049744897959184
# 	original_glcm_Idn: 0.9366496598639455
# 	original_glcm_InverseVariance: 0.19005102040816327
# 	original_glcm_MaximumProbability: 0.7857142857142857
# 	original_glcm_SumEntropy: 0.8544756629494588
# 	original_glcm_SumSquares: 0.10498717982090795
# 	original_glrlm_GrayLevelNonUniformity: 13.163478260869566
# 	original_glrlm_GrayLevelNonUniformityNormalized: 0.6076227263180004
# 	original_glrlm_GrayLevelVariance: 0.1961886368409998
# 	original_glrlm_HighGrayLevelRunEmphasis: 1.8180434782608694
# 	original_glrlm_LongRunEmphasis: 14.306014492753622
# 	original_glrlm_LongRunHighGrayLevelEmphasis: 15.712427536231885
# 	original_glrlm_LongRunLowGrayLevelEmphasis: 13.954411231884059
# 	original_glrlm_LowGrayLevelRunEmphasis: 0.7954891304347825
# 	original_glrlm_RunEntropy: 2.7331156640527756
# 	original_glrlm_RunLengthNonUniformity: 4.847632850241546
# 	original_glrlm_RunLengthNonUniformityNormalized: 0.22538586198044297
# 	original_glrlm_RunPercentage: 0.3359375
# 	original_glrlm_RunVariance: 5.011392877313355
# 	original_glrlm_ShortRunEmphasis: 0.40275411382850246
# 	original_glrlm_ShortRunHighGrayLevelEmphasis: 1.1099370848429952
# 	original_glrlm_ShortRunLowGrayLevelEmphasis: 0.2259583710748792
# 	original_glszm_GrayLevelNonUniformity: 2.5
# 	original_glszm_GrayLevelNonUniformityNormalized: 0.625
# 	original_glszm_GrayLevelVariance: 0.1875
# 	original_glszm_HighGrayLevelZoneEmphasis: 3.25
# 	original_glszm_LargeAreaEmphasis: 817.5
# 	original_glszm_LargeAreaHighGrayLevelEmphasis: 833.25
# 	original_glszm_LargeAreaLowGrayLevelEmphasis: 813.5625
# 	original_glszm_LowGrayLevelZoneEmphasis: 0.4375
# 	original_glszm_SizeZoneNonUniformity: 1.0
# 	original_glszm_SizeZoneNonUniformityNormalized: 0.25
# 	original_glszm_SmallAreaEmphasis: 0.32820194675284703
# 	original_glszm_SmallAreaHighGrayLevelEmphasis: 1.312576946752847
# 	original_glszm_SmallAreaLowGrayLevelEmphasis: 0.08210819675284703
# 	original_glszm_ZoneEntropy: 1.9999999999999987
# 	original_glszm_ZonePercentage: 0.0625
# 	original_glszm_ZoneVariance: 561.5
# 	original_gldm_DependenceEntropy: 2.730418496300719
# 	original_gldm_DependenceNonUniformity: 12.6875
# 	original_gldm_DependenceNonUniformityNormalized: 0.1982421875
# 	original_gldm_DependenceVariance: 3.80859375
# 	original_gldm_GrayLevelNonUniformity: 51.53125
# 	original_gldm_GrayLevelVariance: 0.097412109375
# 	original_gldm_HighGrayLevelEmphasis: 1.328125
# 	original_gldm_LargeDependenceEmphasis: 43.65625
# 	original_gldm_LargeDependenceHighGrayLevelEmphasis: 45.859375
# 	original_gldm_LargeDependenceLowGrayLevelEmphasis: 43.10546875
# 	original_gldm_LowGrayLevelEmphasis: 0.91796875
# 	original_gldm_SmallDependenceEmphasis: 0.05456820141250945
# 	original_gldm_SmallDependenceHighGrayLevelEmphasis: 0.1499458055791761
# 	original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.030723800370842783
# 	original_ngtdm_Busyness: 4.055813953488372
# 	original_ngtdm_Coarseness: 0.18348623853211007
# 	original_ngtdm_Complexity: 0.1703125
# 	original_ngtdm_Contrast: 0.016590499877929685
# 	original_ngtdm_Strength: 0.1834862385321101
